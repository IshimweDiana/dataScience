# %%
import seaborn as scs
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
scs.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = scs.load_dataset("tips")
iris = scs.load_dataset("iris")
titanic = scs.load_dataset("titanic")
planets = scs.load_dataset("planets")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# SCATTER PLOT FOR TIPS

# %%
scs.scatterplot(x="tip",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
scs.scatterplot(x="tip",y="total_bill",data=tips,hue="day",size="size",palette="YlGnBu")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
scs.histplot(tips['tip'], kde= 'true',bins=15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
scs.barplot(x="sex", y="tip", data=tips, palette="YlGnBu")
# Out:
# C:\Users\DOLPHIX ELECTRONICS\AppData\Local\Temp\ipykernel_11024\1025904500.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   scs.barplot(x="sex", y="tip", data=tips, palette="YlGnBu")
# <Axes: xlabel='sex', ylabel='tip'>

# %%
scs.boxplot(x="day", y="tip", data=tips, hue="sex", palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
scs.stripplot(x="day",y="tip", data=tips, hue="sex", dodge='true', palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
scs.jointplot(x="tip",y="total_bill", data=tips)

# %%
scs.jointplot(x="tip",y="total_bill", data=tips, kind="reg",)

# %%
scs.jointplot(x="tip",y="total_bill", data=tips, kind="kde", shade='true', cmap="YlGnBu")
# Out:
# C:\Users\DOLPHIX ELECTRONICS\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=true`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
scs.jointplot(x="tip",y="total_bill", data=tips, kind="hex", cmap="YlGnBu")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
scs.pairplot(titanic.select_dtypes(['number']), hue="pclass")

# %%
numeric_titanic = titanic.select_dtypes(include=['number'])  # Select only numeric columns
correlation_matrix = numeric_titanic.corr()
print(correlation_matrix)
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
numeric_titanic = numeric_titanic.dropna()

# %%
numeric_titanic = numeric_titanic.fillna(0)  # Replace NaNs with 0

# %%
import pandas as pd
for column in numeric_titanic.columns:
    numeric_titanic[column] = pd.to_numeric(numeric_titanic[column], errors='coerce')

# %%
# Select numeric columns
numeric_titanic = titanic.select_dtypes(include=['number'])

# Handle missing values
numeric_titanic = numeric_titanic.fillna(0)  # Replace NaNs with 0 (or use dropna if preferred)

# Compute correlation matrix
correlation_matrix = numeric_titanic.corr()

# Print correlation matrix
print(correlation_matrix)
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481  0.010539 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.361353  0.083081  0.018443 -0.549500
# age       0.010539 -0.361353  1.000000 -0.184664 -0.048786  0.135516
# sibsp    -0.035322  0.083081 -0.184664  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.048786  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.135516  0.159651  0.216225  1.000000

# %%
scs.heatmap(correlation_matrix, annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
scs.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
scs.heatmap(correlation_matrix, annot=True, cmap="icefire")
# Out:
# <Axes: >

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/43.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/43.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/43.6 MB ? eta -:--:--
#     --------------------------------------- 0.8/43.6 MB 2.0 MB/s eta 0:00:22
#     --------------------------------------- 1.0/43.6 MB 1.7 MB/s eta 0:00:25
#    - -------------------------------------- 1.3/43.6 MB 1.7 MB/s eta 0:00:25
#    - -------------------------------------- 1.8/43.6 MB 1.8 MB/s eta 0:00:24
#    - -------------------------------------- 2.1/43.6 MB 1.8 MB/s eta 0:00:24
#    -- ------------------------------------- 2.6/43.6 MB 1.8 MB/s eta 0:00:24
#    -- ------------------------------------- 2.9/43.6 MB 1.8 MB/s eta 0:00:23
#    --- ------------------------------------ 3.4/43.6 MB 1.8 MB/s eta 0:00:23
# ...
